# %% [markdown]
# ## Installations

# %%
# !pip install pypdf

# %%
# !pip install transformers einops accelerate langchain bitsandbytes
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.7/49.7 kB 834.9 kB/s eta 0:00:00a 0:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.2/43.2 kB 1.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 974.6/974.6 kB 7.8 MB/s eta 0:00:00a 0:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 119.8/119.8 MB 13.4 MB/s eta 0:00:0000:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 321.8/321.8 kB 15.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.1/127.1 kB 7.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.0/54.0 kB 3.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 145.0/145.0 kB 8.8 MB/s eta 0:00:00
# ...
#   Attempting uninstall: packaging
#     Found existing installation: packaging 21.3
#     Uninstalling packaging-21.3:
#       Successfully uninstalled packaging-21.3
#   Attempting uninstall: orjson
#     Found existing installation: orjson 3.9.10
#     Uninstalling orjson-3.9.10:
# ...

# %%
# !pip install install sentence_transformers
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 227.1/227.1 kB 1.8 MB/s eta 0:00:00a 0:00:01m
# ...

# %%
# !pip install llama_index
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 15.4/15.4 MB 64.3 MB/s eta 0:00:00:00:010:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 64.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 147.9/147.9 kB 8.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 130.8/130.8 kB 9.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 141.9/141.9 kB 8.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/1.5 MB 54.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 327.4/327.4 kB 20.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 44.0 MB/s eta 0:00:00
# ...
#   Attempting uninstall: nltk
#     Found existing installation: nltk 3.2.4
#     Uninstalling nltk-3.2.4:
#       Successfully uninstalled nltk-3.2.4
#   Attempting uninstall: beautifulsoup4
#     Found existing installation: beautifulsoup4 4.12.2
#     Uninstalling beautifulsoup4-4.12.2:
# ...

# %%
# %pip install llama-index-llms-huggingface
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 402.6/402.6 kB 2.8 MB/s eta 0:00:0000:0100:01
# ...
#   Attempting uninstall: huggingface-hub
#     Found existing installation: huggingface-hub 0.21.4
#     Uninstalling huggingface-hub-0.21.4:
#       Successfully uninstalled huggingface-hub-0.21.4
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
# %pip install llama-index-embeddings-langchain
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import os
from huggingface_hub import login
from kaggle_secrets import UserSecretsClient

secret_label = "your-secret-label"
secret_value = UserSecretsClient().get_secret(secret_label)

login(token=secret_value)
# Out:
# The token has not been saved to the git credentials helper. Pass `add_to_git_credential=True` in this function directly or `--add-to-git-credential` if using via `huggingface-cli` if you want to set the git credential as well.
# Token is valid (permission: read).
# Your token has been saved to /root/.cache/huggingface/token
# Login successful

# %%
from llama_index.core import VectorStoreIndex, SimpleDirectoryReader, ServiceContext, PromptTemplate
from llama_index.llms.huggingface import HuggingFaceLLM
# Out:
# /opt/conda/lib/python3.10/site-packages/pydantic/_internal/_fields.py:151: UserWarning: Field "model_id" has conflict with protected namespace "model_".
#
# You may be able to resolve this warning by setting `model_config['protected_namespaces'] = ()`.
#   warnings.warn(

# %%
documents = SimpleDirectoryReader("/kaggle/input/samplepdf").load_data()

# %%
system_prompt="""
You are a Q&A assistant. Your goal is to answer questions as
accurately as possible based on the instructions and context provided.
"""
query_wrapper_prompt=PromptTemplate("[INST]{query_str}[/INST]")

# %%
query_wrapper_prompt
# Out:
# PromptTemplate(metadata={'prompt_type': <PromptType.CUSTOM: 'custom'>}, template_vars=['query_str'], kwargs={}, output_parser=None, template_var_mappings=None, function_mappings=None, template='[INST]{query_str}[/INST]')

# %%
import torch
from transformers import BitsAndBytesConfig
quant_config = BitsAndBytesConfig(load_in_8bit=True)
llm = HuggingFaceLLM(
    context_window=4096,
    max_new_tokens=256,
    generate_kwargs={"temperature": 0.0, "do_sample": False},
    system_prompt=system_prompt,
    query_wrapper_prompt=query_wrapper_prompt,
    tokenizer_name="meta-llama/Llama-2-7b-chat-hf",
    model_name="meta-llama/Llama-2-7b-chat-hf",
    device_map="auto",
    model_kwargs={"torch_dtype": torch.float16 , "load_in_8bit":True}
)
# Out:
# /opt/conda/lib/python3.10/site-packages/huggingface_hub/file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# config.json:   0%|          | 0.00/614 [00:00<?, ?B/s]
# The `load_in_4bit` and `load_in_8bit` arguments are deprecated and will be removed in the future versions. Please, pass a `BitsAndBytesConfig` object in `quantization_config` argument instead.
# /opt/conda/lib/python3.10/site-packages/huggingface_hub/file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# model.safetensors.index.json:   0%|          | 0.00/26.8k [00:00<?, ?B/s]
# ...
# model-00001-of-00002.safetensors:   0%|          | 0.00/9.98G [00:00<?, ?B/s]
# ...

# %%
# !pip install -U langchain-community
from langchain.embeddings.huggingface import HuggingFaceEmbeddings
from llama_index.core import ServiceContext
from llama_index.embeddings.langchain import LangchainEmbedding

embed_model=LangchainEmbedding(
    HuggingFaceEmbeddings(model_name="sentence-transformers/all-mpnet-base-v2"))
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.2/2.2 MB 1.0 MB/s eta 0:00:00:00:010:01
# ...
# /opt/conda/lib/python3.10/site-packages/langchain_core/_api/deprecation.py:139: LangChainDeprecationWarning: The class `HuggingFaceEmbeddings` was deprecated in LangChain 0.2.2 and will be removed in 0.3.0. An updated version of the class exists in the langchain-huggingface package and should be used instead. To use it run `pip install -U langchain-huggingface` and import as `from langchain_huggingface import HuggingFaceEmbeddings`.
#   warn_deprecated(
# 2024-06-24 10:03:01.050154: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-06-24 10:03:01.050277: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# ...

# %%
# %pip install llama-index-llms-langchain
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 6.6 MB/s eta 0:00:0000:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 32.1 MB/s eta 0:00:00a 0:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 302.9/302.9 kB 16.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 53.0/53.0 kB 3.0 MB/s eta 0:00:00
# ...
#   Attempting uninstall: packaging
#     Found existing installation: packaging 24.1
#     Uninstalling packaging-24.1:
#       Successfully uninstalled packaging-24.1
#   Attempting uninstall: langchain-core
#     Found existing installation: langchain-core 0.2.9
#     Uninstalling langchain-core-0.2.9:
#       Successfully uninstalled langchain-core-0.2.9
#   Attempting uninstall: langchain-text-splitters
#     Found existing installation: langchain-text-splitters 0.2.1
#     Uninstalling langchain-text-splitters-0.2.1:
#       Successfully uninstalled langchain-text-splitters-0.2.1
#   Attempting uninstall: langchain-community
# ...

# %%
from llama_index.core.settings import Settings
Settings.llm = llm
Settings.embed_model = embed_model
Settings.chunk_size = 1024

# %%
from IPython.display import Markdown

# %%
index = VectorStoreIndex.from_documents(documents)
query_engine = index.as_query_engine()

# %%
response=query_engine.query("""give me a flashcard for deadlock and a question to verify understanding""")
# Out:
# /opt/conda/lib/python3.10/site-packages/transformers/generation/configuration_utils.py:410: UserWarning: `do_sample` is set to `False`. However, `temperature` is set to `0.0` -- this flag is only used in sample-based generation modes. You should set `do_sample=True` or unset `temperature`.
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/transformers/generation/configuration_utils.py:415: UserWarning: `do_sample` is set to `False`. However, `top_p` is set to `0.9` -- this flag is only used in sample-based generation modes. You should set `do_sample=True` or unset `top_p`.
#   warnings.warn(

# %%
display(Markdown((f"<b>{response}</b>")))
# Out:
# <b> Flashcard: Deadlock
#
# Deadlock: A situation in which two or more processes are blocked indefinitely, each waiting for the other to release a resource.
#
# Question to verify understanding:
# What are the two main reasons why deadlocks occur in concurrent systems?
#
# Hint: Think about the code snippet provided in the context information.</b>

# %% [markdown]
# ## Chat Engine

# %%
from llama_index.core.memory import ChatMemoryBuffer

memory = ChatMemoryBuffer.from_defaults(token_limit=1500)

chat_engine = index.as_chat_engine(
    chat_mode="context",
    memory=memory,
    system_prompt=system_prompt
)

# %%
response = chat_engine.chat("Code to see virtualisation of memory by os")

# %%
display(Markdown((f"<b>{response}</b>")))
# Out:
# <b> Sure, I'd be happy to help you with that!
#
# In the context of operating systems, virtualization of memory refers to the process of creating a virtual memory space that is separate from the physical memory space of a computer. The operating system uses various techniques to create this virtual memory space, which allows it to provide a more efficient and organized way of managing memory for running programs.
#
# Here are some key concepts related to virtualization of memory in operating systems:
#
# 1. Virtual memory: This is the virtual memory space created by the operating system, which is separate from the physical memory space. The operating system uses various techniques to map the virtual memory space to the physical memory space.
# ...

# %%
response = chat_engine.chat("Process Synchronization")

# %%
display(Markdown((f"<b>{response}</b>")))
# Out:
# <b> Process synchronization refers to the techniques used in operating systems to coordinate the execution of multiple processes or threads to avoid conflicts, ensure mutual exclusion, and maintain data consistency. The goal of process synchronization is to ensure that processes are executed in a way that is both efficient and safe, by avoiding race conditions, deadlocks, and other synchronization-related problems.
#
# There are several techniques used in process synchronization, including:
#
# 1. Mutexes (Mutual Exclusion): A mutex is a synchronization object that allows only one process to access a shared resource at a time. A mutex can be acquired by a process to gain exclusive access to a resource, and it can be released when the process is finished with the resource.
# ...

# %%
response = chat_engine.chat("Deadlock")

# %%
display(Markdown((f"<b>{response}</b>")))
# Out:
# <b> Deadlock is a situation that can occur in concurrent systems, where two or more processes are blocked indefinitely, each waiting for the other to release a resource or take some action. This can happen when there are circular dependencies between the processes, meaning that each process is dependent on the other to release a resource or take an action.
#
# There are four conditions that must be met for a deadlock to occur:
#
# 1. Mutual exclusion: Each process must require exclusive access to a resource.
# 2. Hold-and-wait: Each process must be holding onto a resource that it needs to complete its task.
# 3. No preemption: The system must not be able to forcibly remove a process from a resource it is holding.
# 4. Circular wait: There must be a circular dependence between the processes, where each process is waiting for the other to release a resource or take an action.
#
# To prevent deadlocks, systems can use various techniques, such as:
#
# ...

# %%
from transformers import AutoTokenizer, AutoModelForCausalLM

# Load model and tokenizer
tokenizer = AutoTokenizer.from_pretrained("meta-llama/Llama-2-7b-chat-hf")
model = AutoModelForCausalLM.from_pretrained("meta-llama/Llama-2-7b-chat-hf")

def query_without_rag(question):
    inputs = tokenizer(question, return_tensors="pt")
    outputs = model.generate(**inputs, max_length=200)
    return tokenizer.decode(outputs[0], skip_special_tokens=True)
# Out:
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]

# %%
from llama_index.core import VectorStoreIndex, SimpleDirectoryReader

documents = SimpleDirectoryReader("/kaggle/input/samplepdf").load_data()
index = VectorStoreIndex.from_documents(documents)
query_engine = index.as_query_engine()

def query_with_rag(question):
    response = query_engine.query(question)
    return str(response)

# %%
question = "What are the conditions for deadlock to occur?"

print("Without RAG:")
print(query_without_rag(question))

print("\nWith RAG:")
print(query_with_rag(question))
# Out:
# Without RAG:
# What are the conditions for deadlock to occur?
#
# Deadlock is a situation in which two or more processes are blocked indefinitely, each waiting for the other to release a resource. Deadlock can occur in a system with multiple processes competing for shared resources. Here are the conditions that must be met for a deadlock to occur:
#
# 1. Mutual Exclusion: At least two processes must compete for the same resource.
# 2. Hold and Wait: At least one process must be holding a resource and waiting for another process to release it.
# 3. Wait and Hold: At least one process must be waiting for a resource that is held by another process.
# 4. No Resource: There must be at least two processes that are competing for the same resource.
# 5. Cycle: The processes involved in the deadlock must be part of a cycle, meaning that each process is waiting for another process to release a resource.
# 6
#
# With RAG:
# ...
